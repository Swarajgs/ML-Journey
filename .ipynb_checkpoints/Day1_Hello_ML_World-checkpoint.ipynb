# %% [markdown]
# Day 1 - ML/GenAI Journey Kickoff

# %%
print("Hello, ML World! Kicking off my journey")
# Out:
# Hello, ML World! Kicking off my journey

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randn(100)
y = np.random.randn(100)
plt.scatter(x,y)
plt.title("Random ML Kickoff Scatter")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
